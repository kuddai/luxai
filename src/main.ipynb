# %%
# %load_ext autoreload
# %autoreload 2

# %%
import collections
import datetime
import gc
import json
import os
import pickle
import threading
import time

import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow.keras as keras

from tqdm.notebook import trange

# %%
for gpu in tf.config.list_physical_devices('GPU'):
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
import solution.constants as const
import solution.model as model
import solution.utils as utils
from solution.replay_buffer import ReplayBuffer
from solution.rl import n_step_return

# %%
def get_replay_data(delete_processed_files=False):
    with tf.device('CPU:0'):
        current_chunk = []
        for file_name in os.listdir(const.REPLAY_PATH):
            file_path = os.path.join(const.REPLAY_PATH, file_name)
            print('kuddai file_path', file_path)
            with open(file_path, 'rb') as f:
                data = pickle.load(f)
                current_chunk += data
            
            if delete_processed_files:
                os.unlink(file_path)
    return current_chunk


MAX_REPLAY_BUFFER_SIZE = 5000
replay_buffer = ReplayBuffer(MAX_REPLAY_BUFFER_SIZE)


def replay_buffer_job():
    clear_dir(const.REPLAY_PATH)
    step = 0
    total_sequences = 0
    
    while replay_data_needed:
        chunk = get_replay_data(True)
        if not chunk:
            time.sleep(1.0)
            continue
            
        if step == 0:
            start_time = time.time()
            
        total_sequences += len(chunk)
        
        with tf.device('CPU:0'):
            add_start_time = time.time()
            replay_buffer.add(chunk)
            with tf_writer_lock, tf_writer.as_default(), tf.name_scope('replay_buffer'):
                tf.summary.scalar('buffer size', len(replay_buffer), step)
                tf.summary.scalar('add chunk time', time.time() - add_start_time, step)
                tf.summary.scalar('sequences per second', total_sequences / (time.time() - start_time), step)

        step += 1

# %%
get_replay_data(False)
# Out:
# kuddai file_path /tmp/lux_ai/replays/1bdae962-37be-45ec-ac15-1915dffbad0f
# kuddai file_path /tmp/lux_ai/replays/4c3ba141-e33c-4e0c-b999-af63c04846e4
# kuddai file_path /tmp/lux_ai/replays/d7db9abd-dce7-4990-9c5b-b2edfcf70b1e
# kuddai file_path /tmp/lux_ai/replays/ae28f34e-8f34-445b-b355-888ff463944b
# kuddai file_path /tmp/lux_ai/replays/26bb0e13-7818-4024-9c63-ff5c5a058724
# kuddai file_path /tmp/lux_ai/replays/e83a5959-02a8-4e30-be2c-bea8ae0ca7b0
# kuddai file_path /tmp/lux_ai/replays/16434de8-606f-4b42-b502-ecbbb4d87c42
# kuddai file_path /tmp/lux_ai/replays/5344bf49-bdc1-4ef5-889f-c633eb9469e0
# kuddai file_path /tmp/lux_ai/replays/94409386-d497-46d0-9595-d788e792bbc5
# kuddai file_path /tmp/lux_ai/replays/5200b7c9-79ec-4828-8eff-0b3f8925cc8f
# kuddai file_path /tmp/lux_ai/replays/9f7cbc30-c1f3-4e00-97e6-066dea51ee6d
# kuddai file_path /tmp/lux_ai/replays/71abc974-2dbd-4f54-b899-068173445da3
# kuddai file_path /tmp/lux_ai/replays/33d2e72a-3473-43d0-b25f-a8bb42e55c32
# kuddai file_path /tmp/lux_ai/replays/28ab4c25-2396-4253-955a-c290b838cb4e
# kuddai file_path /tmp/lux_ai/replays/8c2d78cc-5484-4a7e-8c1a-d91f1cdbd0ff
# kuddai file_path /tmp/lux_ai/replays/461544c0-8579-4aaf-9dd4-28a1c3e2701f
# kuddai file_path /tmp/lux_ai/replays/63920c78-8736-4d56-be1d-44dafbe86c8e
# kuddai file_path /tmp/lux_ai/replays/d9a0a73e-1fe3-426f-a939-206dabfdb956
# kuddai file_path /tmp/lux_ai/replays/5820d52d-7163-40a1-873f-4ee5c53c349e
# kuddai file_path /tmp/lux_ai/replays/32a9e8f0-4bf6-431a-828c-949247b105a7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-98d6f4e0f614> in <module>
# ----> 1 get_replay_data(False)
#
# <ipython-input-17-d917f5737bb7> in get_replay_data(delete_processed_files)
#       6             print('kuddai file_path', file_path)
#       7             with open(file_path, 'rb') as f:
# ----> 8                 data = pickle.load(f)
#       9                 current_chunk += data
#      10
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/profiler/trace.py in wrapped(*args, **kwargs)
#     161         with Trace(trace_name, **trace_kwargs):
#     162           return func(*args, **kwargs)
# --> 163       return func(*args, **kwargs)
#     164
#     165     return wrapped
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1564
#    1565     if ret is None:
# -> 1566       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1567
#    1568     if ret is NotImplemented:
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/tensor_conversion_registry.py in _default_conversion_function(***failed resolving arguments***)
#      50 def _default_conversion_function(value, dtype, name, as_ref):
#      51   del as_ref  # Unused.
# ---> 52   return constant_op.constant(value, dtype, name=name)
#      53
#      54
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name)
#     270   """
#     271   return _constant_impl(value, dtype, shape, name, verify_shape=False,
# --> 272                         allow_broadcast=True)
#     273
#     274
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_impl(value, dtype, shape, name, verify_shape, allow_broadcast)
#     281       with trace.Trace("tf.constant"):
#     282         return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
# --> 283     return _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     284
#     285   g = ops.get_default_graph()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in _constant_eager_impl(ctx, value, dtype, shape, verify_shape)
#     306 def _constant_eager_impl(ctx, value, dtype, shape, verify_shape):
#     307   """Creates a constant on the current device."""
# --> 308   t = convert_to_eager_tensor(value, ctx, dtype)
#     309   if shape is None:
#     310     return t
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/constant_op.py in convert_to_eager_tensor(value, ctx, dtype)
#     104       dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     105   ctx.ensure_initialized()
# --> 106   return ops.EagerTensor(value, ctx.device_name, dtype)
#     107
#     108
#
# KeyboardInterrupt:

# %%
def games_data_job():
    clear_dir(const.GAMES_DATA_PATH)
    step = collections.defaultdict(int)
    
    while games_data_needed:
        for file_name in os.listdir(const.GAMES_DATA_PATH):
            file_path = os.path.join(const.GAMES_DATA_PATH, file_name)
            with open(file_path) as f:
                game_data = json.load(f)
                agent_id = game_data['agent_id']
                
                for k, v in game_data.items():
                    if k == 'agent_id':
                        continue
                    
                    if v is None:
                        continue
                        
                    with tf_writer_lock, tf_writer.as_default():
                        with tf.name_scope('game_data/total'):
                            tf.summary.scalar(k, v, step['total'])
                            
                        with tf.name_scope('game_data/%s' % agent_id):
                            tf.summary.scalar(k, v, step[agent_id])
                    
                    
                step['total'] += 1
                step[agent_id] += 1

            os.unlink(file_path)

        time.sleep(1)

# %%
def soft_update(source_variables, target_variables, tau):
    for v_s, v_t in zip(source_variables, target_variables):
        v_t.assign((1 - tau) * v_t + tau * v_s)



def save_model(name, epoch, model, link_path=None):
    if not os.path.exists(const.MODELS_PATH):
        os.makedirs(const.MODELS_PATH)
        
    file_path = os.path.join(const.MODELS_PATH, '%s_%s_%s' % (name, current_time, epoch))
    model.save_weights(file_path)
    
    if link_path is not None:
        tmp_link_path = '%s_tmp' % link_path
        os.symlink(file_path, tmp_link_path)
        os.rename(tmp_link_path, link_path)


def clear_dir(path):
    if not os.path.exists(path):
        os.makedirs(path)
    
    for file_name in os.listdir(path):
        file_path = os.path.join(path, file_name)
        os.unlink(file_path)

# %%
tf.random.set_seed(42)

# %%
BATCH_SIZE = 64
input_shape = [(BATCH_SIZE,) + tuple(i.shape) for i in utils.STATE_SPEC]

network = model.Model()
network.build(input_shape)
network.summary()
#latest_path = tf.train.latest_checkpoint(const.MODELS_PATH)
#print(latest_path)
#network.load_weights(latest_path)

target_network = model.Model()
target_network.build(input_shape)
target_network.trainable = False
target_network.set_weights(network.get_weights())


optimizer = keras.optimizers.Adam(learning_rate=5e-4, clipnorm=40)
loss_fn = keras.losses.MeanSquaredError()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_16 (Sequential)   (64, 256)                 215176
# _________________________________________________________________
# sequential_17 (Sequential)   (64, 64)                  11584
# _________________________________________________________________
# sequential_18 (Sequential)   (2048, 256)               777456
# _________________________________________________________________
# sequential_19 (Sequential)   (64, 32, 32)              1312
# _________________________________________________________________
# sequential_20 (Sequential)   (64, 32, 256)             205568
# _________________________________________________________________
# sequential_21 (Sequential)   (64, 32, 512)             558080
# _________________________________________________________________
# sequential_22 (Sequential)   (64, 32, 7)               133127
# _________________________________________________________________
# sequential_23 (Sequential)   (64, 32, 1)               131585
# =================================================================
# Total params: 2,033,888
# Trainable params: 2,033,888
# Non-trainable params: 0
# _________________________________________________________________

# %%
@tf.function
def learn_from_batch(states, actions, rewards, is_not_done, *, gamma, weights, online_network, target_network):
    #print('Tracing lfb')
    # states is tuple of 5 state_element, state_element has (B, N, *) shape
    target = n_step_return(
        states, actions, rewards, is_not_done,
        gamma=gamma, n=const.N_STEPS, online_network=online_network, target_network=target_network
    )
        
    first_state = tuple([state[:, 0] for state in states])
    first_action = actions[:, 0]
    first_units_mask = tf.cast(states[4][:, 0], dtype=tf.float32)
    
    with tf.GradientTape() as tape:
        q_values = online_network(first_state, training=True)
        prediction = tf.gather(q_values, first_action, axis=-1, batch_dims=2)
        prediction = tf.reduce_sum(prediction * first_units_mask, axis=-1)
        
        td_error = target - prediction
        #loss = tf.reduce_mean(tf.math.pow(td_error, 2))
        loss = tf.reduce_mean(tf.math.pow(td_error, 2) * weights)
    
    gradients = tape.gradient(loss, online_network.trainable_weights)
    grad_min = tf.reduce_mean([tf.reduce_min(g) for g in gradients])
    grad_max = tf.reduce_max([tf.reduce_max(g) for g in gradients])
    grad_l2 = tf.norm([tf.norm(g) for g in gradients])
    optimizer.apply_gradients(zip(gradients, online_network.trainable_weights))
    
    return loss, tf.math.abs(td_error), grad_min, grad_max, grad_l2

# %%
# Setup tensorboard
TB_LOGS_DIR = '/tmp/tb_logs/'

if not os.path.exists(TB_LOGS_DIR):
    os.mkdir(TB_LOGS_DIR)

current_time = datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
current_logs_dir = os.path.join(TB_LOGS_DIR, current_time)
tf_writer = tf.summary.create_file_writer(current_logs_dir)
tf_writer_lock = threading.Lock()

steps = 0

save_model('online', 0, network, const.LATEST_MODEL_SYMLINK_PATH)
save_model('target', 0, target_network, const.TARGET_MODEL_SYMLINK_PATH)

# %%
def stop_threads():
    if 'replay_buffer_thread' in globals():
        print('Stopping replay thread')
        global replay_data_needed
        replay_data_needed = False
        if replay_buffer_thread.is_alive():
            replay_buffer_thread.join()
    
    if 'games_data_thread' in globals():
        print('Stopping games data thread')
        global games_data_needed
        games_data_needed = False
        if games_data_thread.is_alive():
            games_data_thread.join()


stop_threads()


replay_data_needed = True
replay_buffer_thread = threading.Thread(target=replay_buffer_job)
replay_buffer_thread.start()

games_data_needed = True
games_data_thread = threading.Thread(target=games_data_job)
games_data_thread.start()


EPOCHS = 10000000
TARGET_NETWORK_UPDATE_EPISODES = 1000
MODEL_SAVE_PERIOD = 100
INITIAL_DATA_SIZE = BATCH_SIZE * 10


while len(replay_buffer) < INITIAL_DATA_SIZE:
    print('Waiting for data: %s / %s' % (len(replay_buffer), INITIAL_DATA_SIZE))
    time.sleep(1)

        
for epoch in trange(EPOCHS):
    with tf.device('CPU:0'):
        start_time = time.time()
        ts, ind, (batch_states, batch_actions, batch_rewards, batch_is_not_done), td, weights = replay_buffer.get_prioritized(BATCH_SIZE)
        #(batch_states, batch_actions, batch_rewards, batch_is_not_done), td = replay_buffer.get_uniform(BATCH_SIZE)
        get_time = time.time() - start_time
    
    if steps % TARGET_NETWORK_UPDATE_EPISODES == 0:
        print(epoch, 'Updating network')
        target_network.set_weights(network.get_weights())
        save_model('target', epoch, target_network, const.TARGET_MODEL_SYMLINK_PATH)
        gc.collect()
        tf.keras.backend.clear_session()
        # soft_update(network.variables, target_network.variables, 0.01)
    
    if steps % MODEL_SAVE_PERIOD == 0:
        print(epoch, 'Saving model')
        save_model('online', epoch, network, const.LATEST_MODEL_SYMLINK_PATH)
    
    start_time = time.time()
    #loss, new_td_error, grad_min, grad_max, grad_l2 = learn_from_batch(
    #    batch_states, batch_actions, batch_rewards, batch_is_not_done,
    #    gamma=const.GAMMA, weights=None, online_network=network, target_network=target_network)
    loss, new_td_error, grad_min, grad_max, grad_l2 = learn_from_batch(
        batch_states, batch_actions, batch_rewards, batch_is_not_done,
        gamma=const.GAMMA, weights=weights, online_network=network, target_network=target_network)
    learn_time = time.time() - start_time
    
    start_time = time.time()
    replay_buffer.update(ts, ind, new_td_error)
    update_time = time.time() - start_time

    with tf_writer_lock, tf_writer.as_default():
        tf.summary.scalar('loss', loss, step=steps)
        #tf.summary.scalar('avg_version', avg_model_version, step=steps)
        with tf.name_scope('td_error'):
            tf.summary.scalar('before', tf.reduce_mean(td), step=steps)
            tf.summary.scalar('after', tf.reduce_mean(new_td_error), step=steps)
        with tf.name_scope('timing'):
            tf.summary.scalar('get', get_time, step=steps)
            tf.summary.scalar('update', update_time, step=steps)
            tf.summary.scalar('learn', learn_time, step=steps)
        with tf.name_scope('gradients'):
            tf.summary.scalar('min', grad_min, step=steps)
            tf.summary.scalar('max', grad_max, step=steps)
            tf.summary.scalar('l2 norm', grad_l2, step=steps)
            
    steps += 1

stop_threads()
# Out:
# Stopping replay thread
# Stopping games data thread
# Waiting for data: 0 / 640
# Waiting for data: 0 / 640
# Waiting for data: 0 / 640
# Waiting for data: 0 / 640
# Waiting for data: 0 / 640
# kuddai file_path /tmp/lux_ai/replays/ad19815d-2b41-447b-8930-93d69eab604a
# kuddai file_path /tmp/lux_ai/replays/0b7c35d4-c157-4619-b7d1-546d149fa9f3
# Waiting for data: 0 / 640
# Waiting for data: 232 / 640
# Waiting for data: 232 / 640
# Waiting for data: 232 / 640
# kuddai file_path /tmp/lux_ai/replays/3a47b896-7dfe-4440-84ed-91bd03fa66c0
# kuddai file_path /tmp/lux_ai/replays/a5a3333a-7892-4d6d-a907-abf85bd081ed
# kuddai file_path /tmp/lux_ai/replays/779a4337-10b6-4e54-830e-2343c4cc271b
# Waiting for data: 365 / 640
# Waiting for data: 365 / 640
# Waiting for data: 365 / 640
# Waiting for data: 365 / 640
# Waiting for data: 365 / 640
# kuddai file_path /tmp/lux_ai/replays/da870b12-3f17-4239-9418-f0f0f17f30ea
# kuddai file_path /tmp/lux_ai/replays/b4b8ba9e-fcdd-43d1-9383-a2201764d2c9
# Waiting for data: 429 / 640
# Waiting for data: 429 / 640
# Waiting for data: 429 / 640
# Waiting for data: 429 / 640
# kuddai file_path /tmp/lux_ai/replays/00d73fc3-4843-44e9-9e7a-b35ce8d6ee05
# kuddai file_path /tmp/lux_ai/replays/dbec8d15-220c-4cb6-a97f-27bc40103506
# Waiting for data: 571 / 640
# kuddai file_path /tmp/lux_ai/replays/9dd87205-414b-4bc6-b351-159464736ed7
# Waiting for data: 571 / 640
#   0%|          | 0/10000000 [00:00<?, ?it/s]
# tracing get prio
# 0 Updating network
# 0 Saving model
# kuddai file_path /tmp/lux_ai/replays/6ae46df0-31ec-4a02-8a23-f4ae50caa420
# kuddai file_path /tmp/lux_ai/replays/5594e6e9-8076-4f5e-9996-f0d235b01789
# tracing update
# tracing was repl
# kuddai file_path /tmp/lux_ai/replays/535808bd-b75d-45ab-a7b7-5281a968bf1d
# kuddai file_path /tmp/lux_ai/replays/5536e95d-f087-4e3d-b79f-526ff9d178b3
# kuddai file_path /tmp/lux_ai/replays/df6dc7e0-f611-4cdc-87d3-c1ed2282a853
# kuddai file_path /tmp/lux_ai/replays/fdca10bc-d9bb-4c47-b7d8-11fe6eab11b0
# kuddai file_path /tmp/lux_ai/replays/b160a743-b6ef-4d52-b653-b0676ccc9ac1
# kuddai file_path /tmp/lux_ai/replays/9f713515-07c1-46c7-a14e-4a2a41ca3846
# kuddai file_path /tmp/lux_ai/replays/2555156c-9482-46a5-b880-b2f8c465578a
# kuddai file_path /tmp/lux_ai/replays/ab5d1710-0333-4298-b116-2c1850c9a551
# kuddai file_path /tmp/lux_ai/replays/e14f6636-891d-4fa5-96ec-5d2821843ec9
# 100 Saving model
# kuddai file_path /tmp/lux_ai/replays/05dd73d8-84cf-4f1c-8153-66cffd69e73d
# kuddai file_path /tmp/lux_ai/replays/37a6b258-c58f-49a4-b99c-289b9d6eb624
# 200 Saving model
# kuddai file_path /tmp/lux_ai/replays/380567d9-6f2f-4727-a038-0a1b7d151e97
# kuddai file_path /tmp/lux_ai/replays/07e01d14-a17d-4de1-ba9b-e446d535400a
# kuddai file_path /tmp/lux_ai/replays/80a24d0a-75b5-45b8-af71-8006b79af718
# kuddai file_path /tmp/lux_ai/replays/c74a176b-59b3-4785-a277-6ff891a547ed
# kuddai file_path /tmp/lux_ai/replays/668bafba-3b9a-4fe5-89bd-909f8c7ce650
# kuddai file_path /tmp/lux_ai/replays/4d8ecdf8-aeb4-49dd-834b-9c13d51814e5
# 300 Saving model
# 400 Saving model
# kuddai file_path /tmp/lux_ai/replays/7358e1aa-e1ba-46fd-a50e-5c89b8bfe201
# kuddai file_path /tmp/lux_ai/replays/ead0d9c1-0384-495d-b31e-be23db3de99b
# kuddai file_path /tmp/lux_ai/replays/fc1ade31-ea95-4faf-94ab-395e065952dc
# 500 Saving model
# kuddai file_path /tmp/lux_ai/replays/1690e6ba-73b4-48e7-8862-2f68663e570e
# kuddai file_path /tmp/lux_ai/replays/0d7b097e-6690-4061-ac85-7ca42e29f9a0
# kuddai file_path /tmp/lux_ai/replays/74581dbc-9570-476b-899d-3f66dbcb1689
# kuddai file_path /tmp/lux_ai/replays/71d12716-d5be-44e6-904a-23378e48c1c0
# 600 Saving model
# kuddai file_path /tmp/lux_ai/replays/e64060bb-79a7-400d-b07c-1ecf698b91d8
# kuddai file_path /tmp/lux_ai/replays/6e82ad03-6bfe-48ef-a2c3-87c042047edf
# kuddai file_path /tmp/lux_ai/replays/2aebea9b-0ddd-4dfa-b203-f7cabd9d3b71
# kuddai file_path /tmp/lux_ai/replays/7eaebb4b-7d10-4721-b233-c3748c72611b
# 700 Saving model
# kuddai file_path /tmp/lux_ai/replays/1aba98ab-c490-4aa9-a548-6fc674e164c7
# kuddai file_path /tmp/lux_ai/replays/831fe8bb-1da7-4666-98de-c1f08daa2c07
# kuddai file_path /tmp/lux_ai/replays/dc3281c0-e3e2-4091-95d5-e2669c1e1654
# kuddai file_path /tmp/lux_ai/replays/eaa21aeb-e46c-401c-8d89-66e1edf22b8b
# kuddai file_path /tmp/lux_ai/replays/166438aa-18bd-4b90-972d-5dda44852b90
# 800 Saving model
# kuddai file_path /tmp/lux_ai/replays/c8c52708-bab5-40a9-9678-a84efafa8f56
# kuddai file_path /tmp/lux_ai/replays/f7dce035-f5b2-45e9-8df1-955f4d30c4ee
# kuddai file_path /tmp/lux_ai/replays/5317aab9-6c08-45bf-8694-b6f37be70ccb
# kuddai file_path /tmp/lux_ai/replays/6b859ae3-1092-4a2c-8ab2-e6649b264caf
# kuddai file_path /tmp/lux_ai/replays/e71fb81a-2016-436a-bcfc-24dda40f60db
# 900 Saving model
# kuddai file_path /tmp/lux_ai/replays/78127e59-48a7-4687-ac69-23bae11973dc
# kuddai file_path /tmp/lux_ai/replays/bd2e5ac0-5861-46e8-801e-375599f87bc2
# kuddai file_path /tmp/lux_ai/replays/b8131106-beec-422a-8184-c807acb465ee
# kuddai file_path /tmp/lux_ai/replays/3675285b-d4c3-4240-9f51-7c3a76bbe4d9
# 1000 Updating network
# 1000 Saving model
# kuddai file_path /tmp/lux_ai/replays/e2f79380-5860-47e1-968b-de1c2ab00fd9
# kuddai file_path /tmp/lux_ai/replays/6f431c71-b172-4e50-a8ef-904d6bae1338
# kuddai file_path /tmp/lux_ai/replays/c65f0b8c-f963-40da-bc8d-992480f72f8b
# kuddai file_path /tmp/lux_ai/replays/dad47f24-e7db-4656-a264-f7123f8423de
# kuddai file_path /tmp/lux_ai/replays/c0161810-85da-4b14-bf33-1f3407d47218
# kuddai file_path /tmp/lux_ai/replays/94e8b266-3682-464f-803b-c2dc01ed2264
# 1100 Saving model
# kuddai file_path /tmp/lux_ai/replays/57b22977-2f2d-43f2-a360-a1981587341c
# kuddai file_path /tmp/lux_ai/replays/7aee0d8c-cffb-48bb-99ed-bec0177507c2
# kuddai file_path /tmp/lux_ai/replays/94536f67-2184-458c-bca3-0f9f25836be6
# 1200 Saving model
# kuddai file_path /tmp/lux_ai/replays/76b700f1-307c-4a75-a8a3-46d6a7820e1b
# kuddai file_path /tmp/lux_ai/replays/eebfcf13-1a8f-43a0-b0b9-218d70549a2a
# kuddai file_path /tmp/lux_ai/replays/c81712d0-0b69-4eeb-974e-bee6f55b903c
# 1300 Saving model
# kuddai file_path /tmp/lux_ai/replays/cbf6499e-ba29-4339-baed-92ce46c2e3f1
# kuddai file_path /tmp/lux_ai/replays/e1a665b0-4214-426b-bcae-1f64df3384a4
# kuddai file_path /tmp/lux_ai/replays/8b7d9c9f-3b07-4945-b54d-c25da02d2883
# kuddai file_path /tmp/lux_ai/replays/07b1a04b-ca81-4140-8d51-abd9192c7b31
# kuddai file_path /tmp/lux_ai/replays/0353d67e-cbc9-4bc4-bf3b-9bbb68682a01
# 1400 Saving model
# kuddai file_path /tmp/lux_ai/replays/2fffe9bb-1427-48d4-baa0-ca7214cbbe86
# kuddai file_path /tmp/lux_ai/replays/a092db1c-82c8-40db-8d9b-4d67bae6ba57
# kuddai file_path /tmp/lux_ai/replays/4f8a9fad-567b-449b-b6d3-51e337b8a766
# 1500 Saving model
# kuddai file_path /tmp/lux_ai/replays/02532d19-52e0-46dd-88cc-67b7480798c5
# kuddai file_path /tmp/lux_ai/replays/9daeb435-9bbf-4762-bed4-995b32970b7c
# kuddai file_path /tmp/lux_ai/replays/301d5d42-312a-4854-8e50-755d5940dcc9
# kuddai file_path /tmp/lux_ai/replays/73507dd8-2abd-4f1f-8e4d-d76220b8f342
# 1600 Saving model
# kuddai file_path /tmp/lux_ai/replays/1b2edab2-1271-4190-8e68-c9e55f836e16
# kuddai file_path /tmp/lux_ai/replays/a749cecd-beec-4c9b-9a51-7a1ea566f111
# kuddai file_path /tmp/lux_ai/replays/d0cbc19a-e14a-4f5b-b75c-4373d3b62374
# kuddai file_path /tmp/lux_ai/replays/54537f16-3b15-4a91-8a5e-40ddeff9c395
# kuddai file_path /tmp/lux_ai/replays/f99e7964-a4af-43eb-b4ba-80d9f367694d
# 1700 Saving model
# kuddai file_path /tmp/lux_ai/replays/cd663cd7-7059-42f3-9940-f230096162cb
# kuddai file_path /tmp/lux_ai/replays/d9acc9ca-e137-4106-b974-febf5f0da1d5
# kuddai file_path /tmp/lux_ai/replays/cebb2aa6-33bc-47e9-8593-a5595bfe329d
# kuddai file_path /tmp/lux_ai/replays/8e81e55a-e4c6-44ed-b775-eb8bd006f75c
# 1800 Saving model
# kuddai file_path /tmp/lux_ai/replays/1c486530-7698-426b-ae40-6e7e736cd12f
# 1900 Saving model
# kuddai file_path /tmp/lux_ai/replays/7be25a38-68b9-4b8b-bb7a-93fa3ea6a76c
# kuddai file_path /tmp/lux_ai/replays/b6cdba77-5787-40e1-b0a1-eba7c2686f8b
# kuddai file_path /tmp/lux_ai/replays/abf99655-c2a8-4fe4-8fa0-140998082ad1
# 2000 Updating network
# 2000 Saving model
# kuddai file_path /tmp/lux_ai/replays/71e5180b-23a6-4bfa-9bef-a148f46f05e0
# kuddai file_path /tmp/lux_ai/replays/71060119-aee2-4a84-beff-0bd60e4d8a54
# kuddai file_path /tmp/lux_ai/replays/2ffbc342-5ac2-40f0-ad8b-a767a7cc087d
# 2100 Saving model
# kuddai file_path /tmp/lux_ai/replays/10b19e13-a5c9-4d06-b5e7-4f1c1add7f19
# kuddai file_path /tmp/lux_ai/replays/a8c789fc-f681-4d77-993b-1a5e00a53ce9
# kuddai file_path /tmp/lux_ai/replays/2b822e1a-0889-4b77-81e5-82b280706b84
# kuddai file_path /tmp/lux_ai/replays/8cda3841-c013-4f91-a60f-20a0b3f3f64d
# kuddai file_path /tmp/lux_ai/replays/bf0f6d6a-1fff-450e-9457-19a5456c1623
# 2200 Saving model
# kuddai file_path /tmp/lux_ai/replays/e8efd518-e055-4d8d-baa3-3052d82c9325
# 2300 Saving model
# kuddai file_path /tmp/lux_ai/replays/da52fc4b-fc32-414d-9984-41ce2f01f13e
# kuddai file_path /tmp/lux_ai/replays/0912a0c8-8256-4a08-b689-12e39273f9cf
# kuddai file_path /tmp/lux_ai/replays/fc7f3660-afbe-4b6a-aff3-962e11bad7cc
# 2400 Saving model
# kuddai file_path /tmp/lux_ai/replays/f61ad10d-9368-46c7-abe7-e750c247dfde
# kuddai file_path /tmp/lux_ai/replays/535d3a27-b8c9-4a06-956d-27f425d18afa
# kuddai file_path /tmp/lux_ai/replays/a7253fa2-3ef1-4540-9e59-89749976718a
# kuddai file_path /tmp/lux_ai/replays/789ac098-74be-4a80-a4eb-9e8ddf7a5c10
# kuddai file_path /tmp/lux_ai/replays/b3327d00-ce5e-4350-8fc7-31c1f933cc43
# 2500 Saving model
# kuddai file_path /tmp/lux_ai/replays/c52a05ec-4405-4dfe-8c72-2a5707f55661
# kuddai file_path /tmp/lux_ai/replays/dbb62e55-844b-45e7-ac64-4da651e07e38
# kuddai file_path /tmp/lux_ai/replays/b1e5c5f7-7f58-45a4-a44a-e41315d22949
# 2600 Saving model
# kuddai file_path /tmp/lux_ai/replays/dd6c91ef-53df-450d-9720-77b94b0c4b4b
# kuddai file_path /tmp/lux_ai/replays/67a25580-b9cb-4043-9c58-ae5f9746df2b
# 2700 Saving model
# kuddai file_path /tmp/lux_ai/replays/415a2427-b225-4fe3-b4d8-729c87fceb82
# kuddai file_path /tmp/lux_ai/replays/0d859f4b-7c8a-48cf-b8f7-5bcfd757eb1b
# kuddai file_path /tmp/lux_ai/replays/f63a32b8-9ade-4dd4-a304-2df0dea16c44
# kuddai file_path /tmp/lux_ai/replays/c5f2d28f-e457-4b38-8a5b-0b10064e4c2b
# kuddai file_path /tmp/lux_ai/replays/2dbb6c71-961d-46b9-95b2-de16f4523e87
# kuddai file_path /tmp/lux_ai/replays/2af24e25-2deb-4430-b4c1-fe2ac89be170
# 2800 Saving model
# kuddai file_path /tmp/lux_ai/replays/d104f87b-a86d-4631-bfae-41c6a487d8e7
# kuddai file_path /tmp/lux_ai/replays/23729093-8bc6-459e-b0d1-175c2aa8ee32
# kuddai file_path /tmp/lux_ai/replays/67309f95-dabf-43d5-a37d-b877a85e3438
# 2900 Saving model
# kuddai file_path /tmp/lux_ai/replays/a9672c18-184d-4c63-9667-3697047081f5
# 3000 Updating network
# 3000 Saving model
# kuddai file_path /tmp/lux_ai/replays/3c60b0c3-46dd-4d7d-a99d-c3fe0ebfdebf
# kuddai file_path /tmp/lux_ai/replays/d0559642-3ae7-4b4d-9528-1f6a62eb50f7
# kuddai file_path /tmp/lux_ai/replays/eed30d19-ef7b-47c5-b057-61e389767f53
# kuddai file_path /tmp/lux_ai/replays/5285a442-ab93-49cb-b232-40c215fc2b87
# kuddai file_path /tmp/lux_ai/replays/4183e428-456f-4800-992f-2ceb63aa7a28
# kuddai file_path /tmp/lux_ai/replays/6d75a2b9-fb48-445c-9f1d-cbd881779b50
# 3100 Saving model
# kuddai file_path /tmp/lux_ai/replays/4e415219-d1cb-45bd-ae1f-83bdfd15b881
# kuddai file_path /tmp/lux_ai/replays/c5de0896-aead-4f3a-b18e-1fbfd52fc065
# 3200 Saving model
# kuddai file_path /tmp/lux_ai/replays/51c1646f-e369-4b53-bbef-2e9ff02db95b
# kuddai file_path /tmp/lux_ai/replays/05c3e6c0-7b9b-4302-b9ce-c0447a7d589b
# kuddai file_path /tmp/lux_ai/replays/9c248345-43c5-4c90-b81b-79bfff9dadb8
# 3300 Saving model
# 3400 Saving model
# kuddai file_path /tmp/lux_ai/replays/6cb182ef-6e75-484e-9cef-a3f59925a9e0
# kuddai file_path /tmp/lux_ai/replays/7805b51d-be03-452e-9af2-0f2dc5b9d307
# kuddai file_path /tmp/lux_ai/replays/bd26e26f-94b2-43a7-a1f9-38c50a866d4b
# 3500 Saving model
# kuddai file_path /tmp/lux_ai/replays/210624ec-aaab-4e19-9971-bcf20bd1f46e
# 3600 Saving model
# kuddai file_path /tmp/lux_ai/replays/7a9a5cfb-c667-4e05-902d-96afe1ef4b5b
# kuddai file_path /tmp/lux_ai/replays/e4558c30-912f-4804-978a-24e2f630b256
# 3700 Saving model
# kuddai file_path /tmp/lux_ai/replays/16db43f7-2f16-4064-b8d4-801aa4e650e4
# 3800 Saving model
# kuddai file_path /tmp/lux_ai/replays/130b6198-a80c-4a16-ada0-9d1c23076b47
# kuddai file_path /tmp/lux_ai/replays/775a3d91-a3ca-4320-b691-c63dc4a3c88f
# kuddai file_path /tmp/lux_ai/replays/946b899f-eeed-491c-aee3-b407bfa58063
# 3900 Saving model
# 4000 Updating network
# 4000 Saving model
# kuddai file_path /tmp/lux_ai/replays/267f372b-b3a1-43ce-9d8b-441b9760a5a7
# kuddai file_path /tmp/lux_ai/replays/ca227c91-8bb8-4976-85c8-7bd1244a6dec
# kuddai file_path /tmp/lux_ai/replays/27686cf4-8084-48f0-805d-9326d82cbec2
# kuddai file_path /tmp/lux_ai/replays/91c9b4df-828f-4a02-bd4d-125433adc364
# 4100 Saving model
# kuddai file_path /tmp/lux_ai/replays/2f05ec00-2078-49d2-b9d7-ffa003be4290
# kuddai file_path /tmp/lux_ai/replays/e015efe2-0650-4af5-8432-fa737aa3ee82
# kuddai file_path /tmp/lux_ai/replays/46a591de-20a9-4664-add9-b040ee260e5d
# 4200 Saving model
# kuddai file_path /tmp/lux_ai/replays/075dc9b3-b617-465a-b428-3da4066d798a
# kuddai file_path /tmp/lux_ai/replays/415cbd55-76a0-47f6-ad4e-62c585a92ec9
# kuddai file_path /tmp/lux_ai/replays/9145619b-a0bf-4520-b3af-678164b24ffd
# kuddai file_path /tmp/lux_ai/replays/901b8894-af90-4be7-81e4-ca1262315e15
# 4300 Saving model
# kuddai file_path /tmp/lux_ai/replays/0966fb79-77ef-4217-9c0c-042fbe351b42
# kuddai file_path /tmp/lux_ai/replays/6faa2f96-23da-4378-b0a3-e3c77313e8be
# kuddai file_path /tmp/lux_ai/replays/11d9cc0a-307d-4247-a8ad-79aa57578be0
# kuddai file_path /tmp/lux_ai/replays/90ae960a-e74d-4fb8-9d87-b3614ab5a2d4
# 4400 Saving model
# kuddai file_path /tmp/lux_ai/replays/2c809085-a216-4f7e-ade1-2b9f923d7625
# kuddai file_path /tmp/lux_ai/replays/a858eec6-6c25-453c-bfa7-06ed1d7f9c94
# kuddai file_path /tmp/lux_ai/replays/6d510e28-e998-45db-a889-188b6e9f7af5
# 4500 Saving model
# kuddai file_path /tmp/lux_ai/replays/71deb090-f6f1-44a9-adc9-7534ba621ef2
# kuddai file_path /tmp/lux_ai/replays/6f6fb306-5973-4205-b8be-4411c9dd3163
# kuddai file_path /tmp/lux_ai/replays/1c012e6d-4005-4c6c-8eb5-269143027192
# kuddai file_path /tmp/lux_ai/replays/87b53804-6c35-457a-82e8-2c50493ea20d
# 4600 Saving model
# kuddai file_path /tmp/lux_ai/replays/952d047c-297e-4bfd-9472-054ff39cb3a6
# kuddai file_path /tmp/lux_ai/replays/7a7f30cf-7766-4072-b5bd-aae11e68bcb9
# kuddai file_path /tmp/lux_ai/replays/1f2aa74f-311e-4863-994f-3583241caae5
# kuddai file_path /tmp/lux_ai/replays/38d76632-761f-4700-84c8-a540d7cfb64a
# 4700 Saving model
# kuddai file_path /tmp/lux_ai/replays/67403cf8-7360-4835-b34b-5a20a3bbbf5f
# kuddai file_path /tmp/lux_ai/replays/e5854695-85ac-4d60-8064-b43e4da84757
# 4800 Saving model
# kuddai file_path /tmp/lux_ai/replays/16971715-c0ab-4401-b84b-50f21ab8fdc3
# kuddai file_path /tmp/lux_ai/replays/3edbb544-1c0b-4b5f-af33-fe558ec98ccc
# kuddai file_path /tmp/lux_ai/replays/85d26e39-23ff-4819-b1a3-0f321230e33e
# 4900 Saving model
# kuddai file_path /tmp/lux_ai/replays/d2360626-3efa-4927-9a51-ffad6ff59d70
# kuddai file_path /tmp/lux_ai/replays/559b58ca-8125-4aeb-ba94-6fb20d3a44c5
# 5000 Updating network
# 5000 Saving model
# kuddai file_path /tmp/lux_ai/replays/c7920d52-9659-4b05-a184-88995c93bded
# kuddai file_path /tmp/lux_ai/replays/7b14c05b-42d0-4b38-b87e-4ed6f56fe5ad
# 5100 Saving model
# kuddai file_path /tmp/lux_ai/replays/1df73d08-0898-4f73-a048-46b86c125e1d
# 5200 Saving model
# kuddai file_path /tmp/lux_ai/replays/08f09a82-9717-4f07-af04-95c668ce3ccf
# kuddai file_path /tmp/lux_ai/replays/07a2541f-2106-41b2-97a1-87b47f549fc7
# 5300 Saving model
# kuddai file_path /tmp/lux_ai/replays/897ebdb6-85bc-4410-bc00-bc2ed09d3650
# kuddai file_path /tmp/lux_ai/replays/7be0e157-7b88-497d-ba64-21fe329e855e
# kuddai file_path /tmp/lux_ai/replays/30d59b4d-4a42-4508-81b0-5a2c5d5a7cd7
# kuddai file_path /tmp/lux_ai/replays/917f1487-10f9-4d43-9a13-a101ba6a4095
# 5400 Saving model
# kuddai file_path /tmp/lux_ai/replays/6750765b-4beb-49d5-8212-08893e49a97b
# kuddai file_path /tmp/lux_ai/replays/9069652d-f8e6-4fdd-80dc-2f3fa5867f2d
# kuddai file_path /tmp/lux_ai/replays/22695563-4808-4b2c-a5ff-8e5de3727fba
# kuddai file_path /tmp/lux_ai/replays/b4d7ac9e-6ca0-4058-97e4-3c9264a3692d
# 5500 Saving model
# kuddai file_path /tmp/lux_ai/replays/dd5d8f0f-f1a2-4d2d-bf22-10d2aaa770ba
# kuddai file_path /tmp/lux_ai/replays/7f5a1d24-dd05-4ef4-bbe5-05c91038486b
# kuddai file_path /tmp/lux_ai/replays/2fd62eb4-febc-4b46-a5a8-8b904c7f45b2
# kuddai file_path /tmp/lux_ai/replays/984a27f1-d264-4293-a14f-1cc95420aced
# kuddai file_path /tmp/lux_ai/replays/02339cd2-e83c-4f40-8a76-6b2b2810bfb0
# 5600 Saving model
# kuddai file_path /tmp/lux_ai/replays/c399c251-8146-490c-8cc3-53dae97029d9
# kuddai file_path /tmp/lux_ai/replays/3abf2640-5c57-4abf-b1fe-54f28e6cca39
# kuddai file_path /tmp/lux_ai/replays/63638380-9c72-4157-88ff-995250e816b6
# 5700 Saving model
# kuddai file_path /tmp/lux_ai/replays/cde5e58f-bd2a-4ae8-80c8-57f6140d7886
# kuddai file_path /tmp/lux_ai/replays/0ce93d52-3c97-4229-8962-9678fd3ab775
# kuddai file_path /tmp/lux_ai/replays/27befb4c-3318-4da4-9886-abb986b06a2a
# 5800 Saving model
# 5900 Saving model
# kuddai file_path /tmp/lux_ai/replays/ca3eea14-64f1-4825-9bf6-75d055c4cba6
# kuddai file_path /tmp/lux_ai/replays/08ce84ce-0ece-4343-a5cc-e6fa1f315a5c
# 6000 Updating network
# 6000 Saving model
# kuddai file_path /tmp/lux_ai/replays/9f9abd3f-0632-4c35-9f39-f1be0489f76e
# kuddai file_path /tmp/lux_ai/replays/7df40911-df7a-4a99-aad7-6a8bf7e4667b
# 6100 Saving model
# kuddai file_path /tmp/lux_ai/replays/f78def1c-be5d-4aa4-85c2-60051e50a184
# kuddai file_path /tmp/lux_ai/replays/3799d5ee-4333-4f04-ae34-4226ffa01c6e
# 6200 Saving model
# 6300 Saving model
# kuddai file_path /tmp/lux_ai/replays/a0c8a4ca-b677-49ce-9ae7-ef4bc9ab0028
# kuddai file_path /tmp/lux_ai/replays/adcf7750-7f23-4f1c-99ac-b7217df20b5a
# 6400 Saving model
# kuddai file_path /tmp/lux_ai/replays/7fc88096-f99b-4ee8-ab1b-24a3c510aaa1
# 6500 Saving model
# kuddai file_path /tmp/lux_ai/replays/61f9b574-1e0e-4c42-9fba-aee5cc00ed2c
# 6600 Saving model
# kuddai file_path /tmp/lux_ai/replays/d87bfedf-b233-4d5a-902b-f1211409189e
# 6700 Saving model
# kuddai file_path /tmp/lux_ai/replays/5b544074-18de-492f-9b67-6a26644d178e
# kuddai file_path /tmp/lux_ai/replays/8ce24a84-99be-4833-8291-56f41b803703
# kuddai file_path /tmp/lux_ai/replays/9c80c24c-499d-4eb3-8b08-6c1966d53225
# kuddai file_path /tmp/lux_ai/replays/91028aee-69f3-406c-adac-0d885e787f61
# kuddai file_path /tmp/lux_ai/replays/57a5af2f-76d6-4ae4-9f63-27c4bf3d6592
# 6800 Saving model
# kuddai file_path /tmp/lux_ai/replays/91ca8463-e5b1-4796-91c9-63edb03d8278
# kuddai file_path /tmp/lux_ai/replays/997deef2-b235-47d1-b071-a22d0f23e2da
# 6900 Saving model
# kuddai file_path /tmp/lux_ai/replays/5dfdc75c-3a03-48a3-9a6a-4a54970ce994
# kuddai file_path /tmp/lux_ai/replays/256bea1b-9f29-49a9-a247-42ed475edfd5
# kuddai file_path /tmp/lux_ai/replays/c302505b-c283-4a65-8f6e-d1890437da1f
# kuddai file_path /tmp/lux_ai/replays/d03af602-8acb-47c9-8fb2-ef0742983889
# kuddai file_path /tmp/lux_ai/replays/9ba7752d-9834-4f28-b316-b51aeac783da
# kuddai file_path /tmp/lux_ai/replays/3b851545-e5e8-4ad6-bb27-cd1a3c6af703
# kuddai file_path /tmp/lux_ai/replays/1ed9ccb0-094d-4ebe-b36b-5db955a97518
# 7000 Updating network
# 7000 Saving model
# kuddai file_path /tmp/lux_ai/replays/b6c7e173-f1d1-43fc-9a0d-0b6c3b9fcd75
# kuddai file_path /tmp/lux_ai/replays/7e947a05-115b-49da-9de6-f4d72dc02a27
# 7100 Saving model
# kuddai file_path /tmp/lux_ai/replays/7fe5dca5-79ef-4263-b40e-f1d869797627
# kuddai file_path /tmp/lux_ai/replays/63eba44e-5f1b-4e51-b8ff-c3698c1ccc68
# kuddai file_path /tmp/lux_ai/replays/582f073c-6bbe-4d81-9d85-aa799381e035
# 7200 Saving model
# kuddai file_path /tmp/lux_ai/replays/acef1767-3dfa-40a9-ba31-448f26090df8
# kuddai file_path /tmp/lux_ai/replays/c25b7f84-cbc8-4ada-9e54-8162d8e423ec
# kuddai file_path /tmp/lux_ai/replays/7245405f-e24d-4b0e-b39a-cf7b19fbf388
# kuddai file_path /tmp/lux_ai/replays/f08e974b-9dbc-46cf-bf33-0d8807f5a46b
# kuddai file_path /tmp/lux_ai/replays/01b85248-4734-41f2-938e-f7ca2e44aff6
# kuddai file_path /tmp/lux_ai/replays/8773c0e6-2a7c-401b-94de-6b891ee62aad
# 7300 Saving model
# kuddai file_path /tmp/lux_ai/replays/267093ea-eae4-41b2-8ea0-0850e2fe7d33
# kuddai file_path /tmp/lux_ai/replays/c135604c-7591-46ce-ac3f-5a08b0aec117
# kuddai file_path /tmp/lux_ai/replays/aae87f90-6c0e-49fd-b7e6-9e376f073a0d
# 7400 Saving model
# kuddai file_path /tmp/lux_ai/replays/fa0918ea-a63b-4971-a3fc-81e8927903fe
# kuddai file_path /tmp/lux_ai/replays/c84aeb39-24f7-482d-a152-3e337ad7c9c0
# kuddai file_path /tmp/lux_ai/replays/6fd037f3-df43-4ce6-9a8a-cc3a11c99cb7
# 7500 Saving model
# kuddai file_path /tmp/lux_ai/replays/01cc607f-b2b6-4367-b898-0b86b23bce6b
# 7600 Saving model
# kuddai file_path /tmp/lux_ai/replays/11870b57-dae7-48b0-9d69-d8804787d6ef
# kuddai file_path /tmp/lux_ai/replays/eb12699d-b1d8-4404-a85f-c9128b7c618b
# kuddai file_path /tmp/lux_ai/replays/87209017-9156-4b24-ae10-5dba39b685d3
# 7700 Saving model
# kuddai file_path /tmp/lux_ai/replays/73bdaa1f-e87d-492a-a671-3a8b0abf4560
# kuddai file_path /tmp/lux_ai/replays/8188ac93-65d3-40b2-98a8-ff8a7987bf6a
# kuddai file_path /tmp/lux_ai/replays/205afd44-aae8-441b-96cf-5e513bd896f4
# 7800 Saving model
# kuddai file_path /tmp/lux_ai/replays/31fe970a-b34d-4158-b15c-2c3c4ef2cd7a
# kuddai file_path /tmp/lux_ai/replays/62a3ed5a-1b25-4f6d-b709-f4f4bb48998a
# kuddai file_path /tmp/lux_ai/replays/8da5287c-123e-4752-9f45-104a753c4e93
# kuddai file_path /tmp/lux_ai/replays/7f536322-7757-413e-bb32-74844a4e473f
# kuddai file_path /tmp/lux_ai/replays/ab997fbd-aed4-4f86-b3b4-d1407459c312
# 7900 Saving model
# kuddai file_path /tmp/lux_ai/replays/71639ad6-c2a5-4fa9-960f-076d3eb5157d
# kuddai file_path /tmp/lux_ai/replays/8c4bf572-0278-4079-ba0f-032bf6568e93
# kuddai file_path /tmp/lux_ai/replays/c04949ee-2c2c-4254-b0b3-b717febf3f34
# kuddai file_path /tmp/lux_ai/replays/8fb8d5de-0043-407c-bd5a-6f0c2da1b4a4
# kuddai file_path /tmp/lux_ai/replays/edfaa181-2186-4212-aea1-63dcf01bda48
# kuddai file_path /tmp/lux_ai/replays/e547ee21-a552-40b2-ac1a-75c5712f2693
# kuddai file_path /tmp/lux_ai/replays/c3728c0f-3d9c-4e32-99cf-1d4b5c25548f
# 8000 Updating network
# 8000 Saving model
# kuddai file_path /tmp/lux_ai/replays/f6a499b3-cf72-409f-9b2a-7c0afb5cb028
# kuddai file_path /tmp/lux_ai/replays/5af1a8c8-5f28-4b67-a3fb-2c924cdfedc7
# kuddai file_path /tmp/lux_ai/replays/d3865c74-9314-4e1e-8aa1-16ee6e11fef5
# kuddai file_path /tmp/lux_ai/replays/a6a95a66-2188-415c-8667-c3195a860a98
# kuddai file_path /tmp/lux_ai/replays/d5432b38-4896-46a6-9e43-e37dc3163cbd
# kuddai file_path /tmp/lux_ai/replays/9f0cc216-986f-4dcf-855b-6b03eb67ab12
# 8100 Saving model
# kuddai file_path /tmp/lux_ai/replays/bd74a8a8-78d9-4275-be1c-0c29048aea77
# kuddai file_path /tmp/lux_ai/replays/7d8db6ff-eeab-49dc-bbb0-a895e7fd746f
# 8200 Saving model
# kuddai file_path /tmp/lux_ai/replays/b6a755de-33af-451d-9939-419be2f6603d
# kuddai file_path /tmp/lux_ai/replays/11f40d7f-7811-4980-aa14-9d8ea07a77f4
# 8300 Saving model
# kuddai file_path /tmp/lux_ai/replays/ff38874f-f348-49a1-9507-ccf7dc21ad35
# kuddai file_path /tmp/lux_ai/replays/bc25ace2-8435-43c0-ba79-5ccc78e5ece5
# 8400 Saving model
# kuddai file_path /tmp/lux_ai/replays/9090535d-2621-42b4-b248-bcbcdd7a96e1
# kuddai file_path /tmp/lux_ai/replays/cb9b9780-0fba-4046-9754-534bdf6f05a6
# 8500 Saving model
# kuddai file_path /tmp/lux_ai/replays/c4f12b46-7646-44df-bb2a-740ed6271442
# kuddai file_path /tmp/lux_ai/replays/e5b4ccaf-1259-4242-9300-cfc1354a593f
# 8600 Saving model
# kuddai file_path /tmp/lux_ai/replays/0dd4ff90-7039-4567-9185-4507f9a95d8f
# kuddai file_path /tmp/lux_ai/replays/49ddc97f-f454-4ac2-90c9-737bcde5b98e
# kuddai file_path /tmp/lux_ai/replays/4c33605c-404a-4d2d-98ad-69f512bb5919
# kuddai file_path /tmp/lux_ai/replays/40a4696f-ffb4-40ec-b449-7ddc4dd0eaf9
# 8700 Saving model
# kuddai file_path /tmp/lux_ai/replays/8a623d9c-e3cc-43d1-a088-58ba9959a796
# kuddai file_path /tmp/lux_ai/replays/929e04f3-6767-47b2-9b3d-6e2fc23cfc9f
# kuddai file_path /tmp/lux_ai/replays/d9c0a1b9-1536-4642-8c4d-b9a8f1616cb8
# kuddai file_path /tmp/lux_ai/replays/7d05912f-09b0-48dc-bdf1-c1eddd02f57b
# 8800 Saving model
# kuddai file_path /tmp/lux_ai/replays/07dae3b1-b368-4904-bc9a-8c7c2ce79d82
# kuddai file_path /tmp/lux_ai/replays/13e445f8-4e85-4c64-bc1e-67e7a3aa7c48
# kuddai file_path /tmp/lux_ai/replays/94f38608-49db-499f-bd2e-cd8c40c61c64
# kuddai file_path /tmp/lux_ai/replays/58d65df9-5334-4f9c-8002-b778dce6ac49
# kuddai file_path /tmp/lux_ai/replays/3fde0bfe-b210-4f8d-8101-7edf44de44fe
# kuddai file_path /tmp/lux_ai/replays/826f8abc-de01-4579-bcff-c11d29216feb
# 8900 Saving model
# kuddai file_path /tmp/lux_ai/replays/11e9aebd-eb87-4a60-929b-327cbe3738d8
# kuddai file_path /tmp/lux_ai/replays/d8d939e1-129c-464b-a30e-7c6d8f27820f
# kuddai file_path /tmp/lux_ai/replays/7564a97c-58df-464d-a84b-cb61ec09b098
# kuddai file_path /tmp/lux_ai/replays/df02ecd0-e84a-4317-afee-cc9bd27e3aa8
# kuddai file_path /tmp/lux_ai/replays/5219798d-5b40-4c3f-8c50-548e500a75e8
# kuddai file_path /tmp/lux_ai/replays/37020ca4-e0a1-4b2b-8573-fbeb902543cd
# 9000 Updating network
# 9000 Saving model
# kuddai file_path /tmp/lux_ai/replays/49d28bc6-d9e8-4790-b6ac-b779c3cf264e
# kuddai file_path /tmp/lux_ai/replays/9c2922dd-fce4-4bd7-803b-391c1f99bec2
# kuddai file_path /tmp/lux_ai/replays/27232eff-b9ac-4a9a-bfe3-09c63b9f7028
# kuddai file_path /tmp/lux_ai/replays/66ddfdba-b5b5-47a9-89d5-30c330961f85
# 9100 Saving model
# kuddai file_path /tmp/lux_ai/replays/f4280f84-6373-4a3e-ad15-f23c924d7665
# kuddai file_path /tmp/lux_ai/replays/426cfdd1-d1f8-4f98-b847-9aaa533683e8
# 9200 Saving model
# kuddai file_path /tmp/lux_ai/replays/8e883a9a-f57a-4639-b9d3-730a7bee693d
# kuddai file_path /tmp/lux_ai/replays/4fd6b744-130f-455a-b24b-75e5623b58b9
# 9300 Saving model
# kuddai file_path /tmp/lux_ai/replays/af02f353-d93b-4dea-8bca-1adb0703ccd3
# kuddai file_path /tmp/lux_ai/replays/37d05fa7-820e-47b0-95ca-01895bde84e6
# 9400 Saving model
# kuddai file_path /tmp/lux_ai/replays/1e904f75-bc58-43b0-867a-1557cf0a4330
# 9500 Saving model
# kuddai file_path /tmp/lux_ai/replays/9ccbab27-a7da-479d-8cd6-de24fd1355e3
# kuddai file_path /tmp/lux_ai/replays/9dc2ac16-1a5e-4b26-9926-8c533c81f5a2
# kuddai file_path /tmp/lux_ai/replays/49302a87-b785-42f2-9998-0525ec83aff9
# kuddai file_path /tmp/lux_ai/replays/446ed9d2-768d-40e0-be16-8018f781507e
# kuddai file_path /tmp/lux_ai/replays/86269a66-2ab9-4330-8d03-c73b6d45d216
# 9600 Saving model
# 9700 Saving model
# kuddai file_path /tmp/lux_ai/replays/ad2ab76a-dae2-46e4-9c4e-6bcc623f68f8
# kuddai file_path /tmp/lux_ai/replays/5546a8ef-776e-4640-a4a0-dee1ed241a04
# kuddai file_path /tmp/lux_ai/replays/ee92ae13-4352-4e5a-b8e7-89bf8d27c3f4
# 9800 Saving model
# kuddai file_path /tmp/lux_ai/replays/30871e41-0ad7-46d4-8037-628298259e3a
# kuddai file_path /tmp/lux_ai/replays/e31aed23-1d42-4670-b87e-3d8a9f5b6559
# 9900 Saving model
# kuddai file_path /tmp/lux_ai/replays/ba6d5707-ba8f-4f39-b010-f10cab756ad5
# kuddai file_path /tmp/lux_ai/replays/b9e04017-8bd5-4b89-a26d-1ff675af7d81
# kuddai file_path /tmp/lux_ai/replays/c9a24cd0-eeb2-41e7-b5d2-9fa6a9cd6ef9
# 10000 Updating network
# 10000 Saving model
# 10100 Saving model
# kuddai file_path /tmp/lux_ai/replays/ddffaa5f-409f-40cc-ab3b-3622e8c39f9d
# kuddai file_path /tmp/lux_ai/replays/eee8d39d-6f5a-4d33-a84e-bd81b0e6d728
# kuddai file_path /tmp/lux_ai/replays/2014bf2b-f22f-4e20-a657-49081a1417af
# kuddai file_path /tmp/lux_ai/replays/4f9d00e0-8a79-4b87-b8b3-ea7767cb3f1b
# kuddai file_path /tmp/lux_ai/replays/b9d38eb8-355a-4101-86c5-fe137d4cae4f
# 10200 Saving model
# 10300 Saving model
# kuddai file_path /tmp/lux_ai/replays/cef25552-60ad-4f78-906f-31f47bfa6970
# kuddai file_path /tmp/lux_ai/replays/29ca2ad1-8dd7-4ec6-8c10-b4eb346c594e
# kuddai file_path /tmp/lux_ai/replays/096a3e09-f606-4e8c-b845-68d28d2a88bf
# 10400 Saving model
# kuddai file_path /tmp/lux_ai/replays/a5bb064d-525e-4f3e-9e3e-7687a30df587
# kuddai file_path /tmp/lux_ai/replays/367ce677-3de5-42a2-8c21-66eb22f99904
# kuddai file_path /tmp/lux_ai/replays/ae9a347b-80d6-4442-a2d9-b3cb99137218
# kuddai file_path /tmp/lux_ai/replays/d853dd58-5eae-4d41-a828-08ad96cfe034
# kuddai file_path /tmp/lux_ai/replays/5601d20f-c8d2-4987-ab9b-c19a79e6cf02
# 10500 Saving model
# kuddai file_path /tmp/lux_ai/replays/4816f758-d25b-48b8-b3d5-32f0e09de902
# kuddai file_path /tmp/lux_ai/replays/dbee26af-2191-4207-9077-0534fa79e6e0
# 10600 Saving model
# kuddai file_path /tmp/lux_ai/replays/09240de8-9ba7-4685-a5d6-b284ad4d6af7
# kuddai file_path /tmp/lux_ai/replays/df9238f7-bc48-4640-bb89-c928f801453a
# kuddai file_path /tmp/lux_ai/replays/e7aed1af-8d46-4260-8969-0547d0fbb390
# kuddai file_path /tmp/lux_ai/replays/fe662703-034a-42bb-b4ab-a6d866688350
# kuddai file_path /tmp/lux_ai/replays/035f001f-ccca-4871-bbc4-73a47f66128d
# 10700 Saving model
# kuddai file_path /tmp/lux_ai/replays/4d69a40e-393b-4a47-af14-f174c8f65a38
# kuddai file_path /tmp/lux_ai/replays/97af6242-8607-444d-a39e-a4c51089b6c5
# kuddai file_path /tmp/lux_ai/replays/40cdd888-ed2c-4783-899f-1d7bb8309746
# 10800 Saving model
# kuddai file_path /tmp/lux_ai/replays/ae535426-02a2-4aad-b596-0520a758c2f3
# kuddai file_path /tmp/lux_ai/replays/de6237e4-8b58-4c75-b86c-ed980638abfd
# 10900 Saving model
# kuddai file_path /tmp/lux_ai/replays/2d7f9f89-b78b-4a71-be96-99e33234cdfd
# 11000 Updating network
# 11000 Saving model
# kuddai file_path /tmp/lux_ai/replays/6f05c115-3483-400a-9011-0c5ba60111f3
# kuddai file_path /tmp/lux_ai/replays/6e8c8008-fbc9-46ec-a737-d725ad7fd75c
# kuddai file_path /tmp/lux_ai/replays/79f4e700-ddcf-40a9-bf14-ec6477054212
# kuddai file_path /tmp/lux_ai/replays/378a5ac0-b40b-4a3a-b91f-34beeaee5dd1
# kuddai file_path /tmp/lux_ai/replays/316be6d4-ae11-4a5a-bd50-52fcfa61a8c2
# kuddai file_path /tmp/lux_ai/replays/51eb3446-7b4e-4fdc-b564-d5d14511cf98
# 11100 Saving model
# 11200 Saving model
# kuddai file_path /tmp/lux_ai/replays/3267828f-76d8-4199-8cbc-c44db71d5e89
# kuddai file_path /tmp/lux_ai/replays/88050a61-60ba-4b16-9e94-c5ed3fc9a0a8
# kuddai file_path /tmp/lux_ai/replays/f547ef42-3694-4b1d-ac21-9ecdce34e715
# 11300 Saving model
# kuddai file_path /tmp/lux_ai/replays/4f9922da-e1b0-46ef-bc62-e5806f53c63e
# 11400 Saving model
# kuddai file_path /tmp/lux_ai/replays/a340d31a-9fd7-40cc-9bba-c9d7982775dd
# kuddai file_path /tmp/lux_ai/replays/1539c43d-aac3-40ef-b9dd-668521f1c190
# kuddai file_path /tmp/lux_ai/replays/8f804bb6-eee4-4c33-bbeb-0123ea3d02fb
# kuddai file_path /tmp/lux_ai/replays/43cd19d0-060b-437a-b081-76c5af953d29
# 11500 Saving model
# kuddai file_path /tmp/lux_ai/replays/46e6afc2-e954-4fa1-9fb1-4688165d6f60
# kuddai file_path /tmp/lux_ai/replays/013370aa-5fed-4311-80a3-b7d915bd2d9a
# kuddai file_path /tmp/lux_ai/replays/9e7bc024-875a-4680-ad2a-2100bf015f02
# 11600 Saving model
# kuddai file_path /tmp/lux_ai/replays/3b8e061f-b571-49f7-ac81-c63f01f27c82
# kuddai file_path /tmp/lux_ai/replays/81d9b28d-5031-432a-80a7-e4045ae144d2
# kuddai file_path /tmp/lux_ai/replays/a7269001-c130-4ff0-ba9e-f206ad2ea935
# 11700 Saving model
# kuddai file_path /tmp/lux_ai/replays/92f7fee4-9a61-4aac-a8e5-6af6fa2a038c
# kuddai file_path /tmp/lux_ai/replays/7652ba24-bfa3-46eb-b8b8-07ce55c1922a
# kuddai file_path /tmp/lux_ai/replays/1b2812b0-f3fc-48ec-9166-95038ea85dda
# 11800 Saving model
# kuddai file_path /tmp/lux_ai/replays/edf63873-e1f0-4590-bc78-9ad45741ab40
# kuddai file_path /tmp/lux_ai/replays/9b2e1a0f-dbfb-42ca-9bb9-2e1997a86892
# kuddai file_path /tmp/lux_ai/replays/31200871-f4cf-4c15-8988-86bb96228a2d
# kuddai file_path /tmp/lux_ai/replays/88659d47-bba1-4e0f-a558-0093dd245e43
# 11900 Saving model
# kuddai file_path /tmp/lux_ai/replays/c3d2492e-6d55-43de-940c-8a191fd83a17
# kuddai file_path /tmp/lux_ai/replays/3f5ae24c-47ae-4147-9586-e1a711246586
# kuddai file_path /tmp/lux_ai/replays/4e55b26b-eb15-4739-808d-b9bebf3a5f80
# 12000 Updating network
# 12000 Saving model
# kuddai file_path /tmp/lux_ai/replays/9f78c87c-89c0-4dfe-9e16-8b21ddaa46c7
# kuddai file_path /tmp/lux_ai/replays/6c89f6a2-1fbc-416e-bbd4-61ef57c85f68
# 12100 Saving model
# kuddai file_path /tmp/lux_ai/replays/8995897e-10f8-47de-9ad2-d37961a3e38e
# kuddai file_path /tmp/lux_ai/replays/1c45b0ed-7b3b-4b60-9014-e60101451576
# 12200 Saving model
# kuddai file_path /tmp/lux_ai/replays/18d977b0-e096-4cbb-9b5a-ea6a1b13bab6
# kuddai file_path /tmp/lux_ai/replays/11266494-947f-472a-930e-741c4c2b41f3
# kuddai file_path /tmp/lux_ai/replays/0069a765-23a2-4781-8ccf-3dbeacf2afca
# 12300 Saving model
# kuddai file_path /tmp/lux_ai/replays/16395561-c3fd-4fde-9495-e8ca2f20a438
# kuddai file_path /tmp/lux_ai/replays/0fb675dd-ff90-4642-9043-44296ee19f47
# 12400 Saving model
# kuddai file_path /tmp/lux_ai/replays/5cc18e98-0fb1-4d0a-858a-4c1c49949bf2
# kuddai file_path /tmp/lux_ai/replays/15f6afaf-0558-4bca-bab4-64529f393364
# kuddai file_path /tmp/lux_ai/replays/a663df1d-4b79-48b8-9482-2f44c49c2bfe
# kuddai file_path /tmp/lux_ai/replays/f1848579-89ad-42fa-a613-e7c7ef298f84
# kuddai file_path /tmp/lux_ai/replays/34fc6e27-40c9-4b8e-b384-051170727993
# 12500 Saving model
# kuddai file_path /tmp/lux_ai/replays/d9441da3-0b94-4e7b-9163-df2a6d7e54ff
# 12600 Saving model
# kuddai file_path /tmp/lux_ai/replays/92adb4f5-f308-422e-a5bc-f6757158741b
# kuddai file_path /tmp/lux_ai/replays/a67d87f3-35e7-4df3-97e8-c8d21844a659
# kuddai file_path /tmp/lux_ai/replays/f20b4d85-9574-4c72-98ce-d06d93302c89
# kuddai file_path /tmp/lux_ai/replays/3c55fad9-464e-438d-a5b6-bb03bdd8524e
# 12700 Saving model
# kuddai file_path /tmp/lux_ai/replays/03e15f7f-0f21-4a05-bbf7-442fffaf35ae
# 12800 Saving model
# kuddai file_path /tmp/lux_ai/replays/4c9caef6-8010-4b9d-8fb9-b74d1eeb2627
# kuddai file_path /tmp/lux_ai/replays/b285d6a6-ba0b-4520-b092-c21092866b4d
# kuddai file_path /tmp/lux_ai/replays/76cebafc-59d0-46ca-9fbf-3a0ce93e2095
# kuddai file_path /tmp/lux_ai/replays/bf3f39ba-0ae2-472f-b789-9eaf371b3c80
# 12900 Saving model
# kuddai file_path /tmp/lux_ai/replays/bc9a04d1-234a-4df9-99b9-ed3628008251
# kuddai file_path /tmp/lux_ai/replays/7e848558-b3fe-4f86-a745-4494421e3a57
# kuddai file_path /tmp/lux_ai/replays/19129ee7-7285-40d6-9da7-60c58fede358
# 13000 Updating network
# 13000 Saving model
# 13100 Saving model
# kuddai file_path /tmp/lux_ai/replays/bc4ea411-75ae-47c0-b9dd-743faf75934a
# kuddai file_path /tmp/lux_ai/replays/3444ae90-8e1f-4381-9dc4-2955eb74e5a1
# 13200 Saving model
# kuddai file_path /tmp/lux_ai/replays/8a97a05c-dad4-411e-8c35-2c2f391b84d5
# kuddai file_path /tmp/lux_ai/replays/a7914d60-e80d-43b2-9b67-335ff4939d68
# 13300 Saving model
# kuddai file_path /tmp/lux_ai/replays/670843f2-f849-4101-893e-c97331798d0c
# kuddai file_path /tmp/lux_ai/replays/1f0d67a8-a04d-4e0a-b135-13ed72709a64
# 13400 Saving model
# kuddai file_path /tmp/lux_ai/replays/dbb88bf7-7b97-4f21-b79e-a269aae1ef0b
# kuddai file_path /tmp/lux_ai/replays/24cedb9f-4585-4a52-8c4f-27d2ce56346a
# kuddai file_path /tmp/lux_ai/replays/6ff462f3-0a76-475b-84b4-6af2972a94c8
# kuddai file_path /tmp/lux_ai/replays/e58639dd-44cf-44eb-abc9-5f594de39120
# kuddai file_path /tmp/lux_ai/replays/c919b21e-683f-4172-ab3c-d2afba034bea
# kuddai file_path /tmp/lux_ai/replays/a43f6b69-a6d3-4fc6-9d36-241c278c8394
# kuddai file_path /tmp/lux_ai/replays/7a2de6e4-e909-4bd0-957e-df20c0d8ece9
# 13500 Saving model
# kuddai file_path /tmp/lux_ai/replays/bfde5cec-0841-426e-af4b-4c06ead3f42b
# kuddai file_path /tmp/lux_ai/replays/8f98be31-ab69-4721-b998-c0cd755d8cb1
# kuddai file_path /tmp/lux_ai/replays/3bbaf79a-8f08-4305-9cbb-80ecd2b83f60
# 13600 Saving model
# kuddai file_path /tmp/lux_ai/replays/5326cce5-c388-4b0d-b760-2a12cb242dc8
# kuddai file_path /tmp/lux_ai/replays/7463c984-7d03-4c7e-a1a2-b7e3ff2fe39e
# 13700 Saving model
# kuddai file_path /tmp/lux_ai/replays/0948e5eb-8446-440e-b057-d06f80877c0b
# 13800 Saving model
# kuddai file_path /tmp/lux_ai/replays/7c37a4d1-c64c-4640-bc15-99244d60d731
# kuddai file_path /tmp/lux_ai/replays/fe8ba4e4-7128-4eb7-b38e-1ae3954bb08c
# 13900 Saving model
# kuddai file_path /tmp/lux_ai/replays/b6729fce-976b-46ad-b3ca-8d4a1fd0d24e
# 14000 Updating network
# 14000 Saving model
# kuddai file_path /tmp/lux_ai/replays/42b80027-c265-45b7-b8e3-24838cbc1af0
# kuddai file_path /tmp/lux_ai/replays/07ff0e68-23ac-4d0b-b4a8-e25360ff35c8
# kuddai file_path /tmp/lux_ai/replays/fa73306f-2b79-437f-a76c-64a8ad32e839
# kuddai file_path /tmp/lux_ai/replays/c9215202-fa6c-4f57-b23c-12a732a5e623
# kuddai file_path /tmp/lux_ai/replays/2ce01c47-f349-4be9-8392-30a9beea5d12
# kuddai file_path /tmp/lux_ai/replays/c545a54b-bf53-4e68-9e5a-21fc2acd764a
# kuddai file_path /tmp/lux_ai/replays/4d23a3d2-09f1-4042-9c30-2ce9e784d5af
# kuddai file_path /tmp/lux_ai/replays/e158448c-2fe3-430b-8ff2-bfec98c990f2
# 14100 Saving model
# kuddai file_path /tmp/lux_ai/replays/6337e712-d20d-4ac5-9b7d-09722dbad0a9
# kuddai file_path /tmp/lux_ai/replays/94b1defb-6f39-41af-8a52-f891e1e4960a
# 14200 Saving model
# kuddai file_path /tmp/lux_ai/replays/3d1854bf-5c9f-4aff-a181-17c0dc725a5d
# kuddai file_path /tmp/lux_ai/replays/df5bb61b-54cd-4a41-928b-177f31417802
# kuddai file_path /tmp/lux_ai/replays/8803b140-82fd-4a51-9303-23c1374111e2
# kuddai file_path /tmp/lux_ai/replays/96cdf89b-44df-4d32-8cc5-e58b2cb4d3e1
# 14300 Saving model
# kuddai file_path /tmp/lux_ai/replays/68bfeb50-f2be-4fa1-a206-3b26c08f9de0
# 14400 Saving model
# kuddai file_path /tmp/lux_ai/replays/7d0caeec-147d-43a0-a4e6-870b56204183
# kuddai file_path /tmp/lux_ai/replays/8b538b49-2f1c-4a0b-b552-df9334d60538
# kuddai file_path /tmp/lux_ai/replays/a8b518aa-5e37-4018-8656-6c34ec428dcf
# kuddai file_path /tmp/lux_ai/replays/08fca7a7-c641-4b55-97ea-3ad8731663d8
# 14500 Saving model
# kuddai file_path /tmp/lux_ai/replays/b8268214-06b9-4ad2-bd7a-8ec3206f00bb
# kuddai file_path /tmp/lux_ai/replays/c6278b67-78b9-4546-8323-c02817f8e04f
# 14600 Saving model
# kuddai file_path /tmp/lux_ai/replays/efd9875c-38fc-4436-9339-ca8da892110a
# kuddai file_path /tmp/lux_ai/replays/925db321-befd-4801-83f0-17624e77c120
# kuddai file_path /tmp/lux_ai/replays/823e774f-90d8-48f5-b69c-1ffc82d31798
# kuddai file_path /tmp/lux_ai/replays/4dd65b8b-002e-4d23-97d4-f464648b4c7a
# kuddai file_path /tmp/lux_ai/replays/1c381c4c-2b28-4a39-aa0f-f91dcc9809cc
# kuddai file_path /tmp/lux_ai/replays/c934082f-826f-4e83-b1ed-5f53174d216a
# kuddai file_path /tmp/lux_ai/replays/3ef38f1b-9e67-4c3f-a969-302d011e25b4
# kuddai file_path /tmp/lux_ai/replays/684209b5-2db0-4fbf-8342-86d0d98a4b62
# 14700 Saving model
# kuddai file_path /tmp/lux_ai/replays/2178f402-db54-4bd0-9fcf-05bcee559244
# kuddai file_path /tmp/lux_ai/replays/12effdfa-51cd-4184-b1dd-1709d2457811
# kuddai file_path /tmp/lux_ai/replays/2d6213d2-bdbd-49d1-9aed-b9a1b194f514
# kuddai file_path /tmp/lux_ai/replays/1d43ab1d-313f-4bf2-85ea-06c1a59a2cae
# kuddai file_path /tmp/lux_ai/replays/cd1fc641-8817-4086-8f1f-1d89ea4f65dc
# kuddai file_path /tmp/lux_ai/replays/fdd0ca67-53c5-466f-934a-124d9ed41264
# 14800 Saving model
# kuddai file_path /tmp/lux_ai/replays/50729262-6dc1-44c1-ad9c-aad2be26dc01
# kuddai file_path /tmp/lux_ai/replays/34f75280-6c16-41ef-890f-5dde009b4f84
# kuddai file_path /tmp/lux_ai/replays/d186eb75-f967-4510-9de0-2ed3a5d002c4
# 14900 Saving model
# kuddai file_path /tmp/lux_ai/replays/225b515a-9855-422e-9a65-159a6dbfa935
# kuddai file_path /tmp/lux_ai/replays/37c79894-5d78-4495-b4be-26cd48fea48f
# kuddai file_path /tmp/lux_ai/replays/9ff70137-4de3-4137-a374-eef1ce1d4087
# 15000 Updating network
# 15000 Saving model
# 15100 Saving model
# kuddai file_path /tmp/lux_ai/replays/17efea0b-f9bb-422a-ae93-18dd6f657bdc
# kuddai file_path /tmp/lux_ai/replays/95843e83-72b3-4ee5-87a1-2241033545b5
# kuddai file_path /tmp/lux_ai/replays/9581c440-edc9-48e1-a03d-ee9ff168147f
# 15200 Saving model
# 15300 Saving model
# kuddai file_path /tmp/lux_ai/replays/d1b6d1d9-b0ea-4f25-b0c3-e633b9c8582e
# kuddai file_path /tmp/lux_ai/replays/7229f16f-edf2-48f7-8613-e3336f265c10
# kuddai file_path /tmp/lux_ai/replays/bf598791-8336-4d36-ab9d-1611b5695158
# 15400 Saving model
# kuddai file_path /tmp/lux_ai/replays/1b2c491b-06f6-42be-9502-aacca0257d8a
# kuddai file_path /tmp/lux_ai/replays/1ad0c337-2d55-49f3-8134-74d5427fc336
# kuddai file_path /tmp/lux_ai/replays/4c2f8d5f-819e-4e24-ae24-2cee7d676a01
# kuddai file_path /tmp/lux_ai/replays/aebaa886-4d0e-4f97-9ece-c6cfa0451a85
# 15500 Saving model
# kuddai file_path /tmp/lux_ai/replays/17d626fd-93bc-452c-857f-5cf951c4b730
# kuddai file_path /tmp/lux_ai/replays/e148d38c-93b5-42c4-9317-0380ff295d28
# kuddai file_path /tmp/lux_ai/replays/14462a0a-39bb-42d9-8187-93682a038770
# kuddai file_path /tmp/lux_ai/replays/1846f355-4837-4aa8-a609-8bc891bbf223
# 15600 Saving model
# kuddai file_path /tmp/lux_ai/replays/8d641a91-a8fc-4f9e-ac21-49eb40427088
# 15700 Saving model
# kuddai file_path /tmp/lux_ai/replays/7fe4541a-a4ab-469a-8ba5-bcfa28593286
# kuddai file_path /tmp/lux_ai/replays/157519bc-154c-48f5-a049-aefddcf4c59c
# 15800 Saving model
# kuddai file_path /tmp/lux_ai/replays/d93aa543-9ddc-46ca-85e1-d5e50a216712
# kuddai file_path /tmp/lux_ai/replays/d7300990-49ef-4e0a-8d4b-e1f98193b50f
# kuddai file_path /tmp/lux_ai/replays/320cdb1c-66d2-453d-9326-975b7c095715
# kuddai file_path /tmp/lux_ai/replays/2555b119-b8c0-4cf3-96e5-82448169d9c1
# 15900 Saving model
# kuddai file_path /tmp/lux_ai/replays/4b46e058-128b-4d8b-8bbe-dd65f234ec5c
# kuddai file_path /tmp/lux_ai/replays/856029bc-da45-4143-944b-08959cae96cc
# kuddai file_path /tmp/lux_ai/replays/dcf66cb8-de04-4580-bf4d-f52d9127c429
# 16000 Updating network
# kuddai file_path /tmp/lux_ai/replays/168f4303-d9d0-4e9f-a9b1-ff9346ee8f7b
# 16000 Saving model
# kuddai file_path /tmp/lux_ai/replays/ad8264a4-9169-4ed7-96b7-9ae424642f57
# kuddai file_path /tmp/lux_ai/replays/8a60a1e7-2bce-4997-b433-062d51c24ff8
# 16100 Saving model
# kuddai file_path /tmp/lux_ai/replays/32e2221c-8d46-4b5b-ab16-872c8c48b3e9
# kuddai file_path /tmp/lux_ai/replays/975f16a2-671c-43f0-b2a4-5ccd99c3dcae
# 16200 Saving model
# kuddai file_path /tmp/lux_ai/replays/8a87f778-861d-4239-8129-bdf06a2003b4
# kuddai file_path /tmp/lux_ai/replays/0628f340-72c2-4cdb-bb59-a7387bee5ec4
# kuddai file_path /tmp/lux_ai/replays/cbac0dd3-3c90-4167-9070-d43e59d80e00
# 16300 Saving model
# 16400 Saving model
# kuddai file_path /tmp/lux_ai/replays/a2e77007-41bf-49ef-b186-cb62af7f3bf8
# kuddai file_path /tmp/lux_ai/replays/316fc9af-0748-4a7b-b487-f08ff0123aa5
# 16500 Saving model
# kuddai file_path /tmp/lux_ai/replays/8dc82e02-66a6-439b-a10d-a5f48b93f6b9
# kuddai file_path /tmp/lux_ai/replays/f562c18d-b758-4533-b517-e2db190de3f9
# kuddai file_path /tmp/lux_ai/replays/a35e8d84-902c-4045-a25b-fef6e249b1c4
# kuddai file_path /tmp/lux_ai/replays/4e00756e-ff55-49cf-96d1-915973547a90
# 16600 Saving model
# kuddai file_path /tmp/lux_ai/replays/7efb6e56-cf1b-44db-b5f4-f7abe69d5ded

# %%
stop_threads()
